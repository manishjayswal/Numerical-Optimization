# %% [markdown]
# # DS-211 : Aug-2021 : PS-3
#
# # **Ques:1**:**Conjugate Gradient**
#
# (a) [0.5 point]
#
# ![Screenshot from 2021-09-05 15-04-34.png](data:image/png;base64,...)

# %% [markdown]
# (b) [0.5 point]
#
# # Repeat (a) using preconditioned Conjugate gradient and check whether is there any improvement in convergence.

# %% [markdown]
# (c) [1 point]
#
# ![Screenshot from 2021-09-05 15-09-01.png](data:image/png;base64,...)

# %% [markdown]
# (c) [1 point]
#
# # Refer to Question-1 of problem set 1 and solve the least squares problem for optimal 'n' using CG algorithm.

# %% [markdown]
# # **Ques:2** : **Trust Region Strategy**
#
# (a) [1 point]
#
# ![Screenshot from 2021-09-05 16-01-28.png](data:image/png;base64,...)

# %% [markdown]
# (b) [1 point]
#
# ![Screenshot from 2021-09-05 16-08-22.png](data:image/png;base64,...)
